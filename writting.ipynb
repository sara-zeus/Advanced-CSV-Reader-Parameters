# %% [markdown]
# <a href="https://colab.research.google.com/github/sara-zeus/Advanced-CSV-Reader-Parameters/blob/main/writting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ac3f436-295b-4629-86bd-a266a233c0ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ac3f436-295b-4629-86bd-a266a233c0ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('hrdata.csv')

# %%
df.head()
# Out:
#              Name Hire Date   Salary  Sick Days remaining
# 0  Graham Chapman  03/15/14  50000.0                   10
# 1     John Cleese  06/01/15  65000.0                    8
# 2       Eric Idle  05/12/14  45000.0                   10
# 3     Terry Jones  11/01/13  70000.0                    3
# 4   Terry Gilliam  08/12/14  48000.0                    7

# %%
df=pd.read_csv('hrdata.csv', index_col='Name')

# %%
df.head()
# Out:
#                Hire Date   Salary  Sick Days remaining
# Name
# Graham Chapman  03/15/14  50000.0                   10
# John Cleese     06/01/15  65000.0                    8
# Eric Idle       05/12/14  45000.0                   10
# Terry Jones     11/01/13  70000.0                    3
# Terry Gilliam   08/12/14  48000.0                    7

# %%
print(type(df['Hire Date'][0]))
# Out:
# <class 'str'>

# %%
#Converting to Time Stamp
df=pd.read_csv('hrdata.csv', index_col='Name', parse_dates=['Hire Date'])

# %%
df.head()
# Out:
#                 Hire Date   Salary  Sick Days remaining
# Name
# Graham Chapman 2014-03-15  50000.0                   10
# John Cleese    2015-06-01  65000.0                    8
# Eric Idle      2014-05-12  45000.0                   10
# Terry Jones    2013-11-01  70000.0                    3
# Terry Gilliam  2014-08-12  48000.0                    7

# %%
print(type(df['Hire Date'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
#Renaming Column Names
df=pd.read_csv('hrdata.csv', index_col='Employee', parse_dates=['Hired'],
               header=0,
               names=['Employee', 'Hired','Salary', "Sick Days"])

# %%
df.head()
# Out:
#                     Hired   Salary  Sick Days
# Employee
# Graham Chapman 2014-03-15  50000.0         10
# John Cleese    2015-06-01  65000.0          8
# Eric Idle      2014-05-12  45000.0         10
# Terry Jones    2013-11-01  70000.0          3
# Terry Gilliam  2014-08-12  48000.0          7

# %%
df.loc['Cookies Cat']= ['2-16-07-04', 20000.00,0]

# %%
print(df)
# Out:
#                               Hired   Salary  Sick Days
# Employee
# Graham Chapman  2014-03-15 00:00:00  50000.0         10
# John Cleese     2015-06-01 00:00:00  65000.0          8
# Eric Idle       2014-05-12 00:00:00  45000.0         10
# Terry Jones     2013-11-01 00:00:00  70000.0          3
# Terry Gilliam   2014-08-12 00:00:00  48000.0          7
# Michael Palin   2013-05-23 00:00:00  66000.0          8
# Cookies Cat              2-16-07-04  20000.0          0

# %%
df.to_csv('hrdata_modified.csv')
